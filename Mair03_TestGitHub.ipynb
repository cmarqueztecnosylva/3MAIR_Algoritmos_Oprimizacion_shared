# %%
# !pip install sorting
# Out:
# ...
#   Created wheel for sorting: filename=sorting-1.0.3-cp36-none-any.whl size=5883 sha256=931454fc77de95c2ba1a5fb1016fba7e96a55c357006892219f5c84e7b149b53
#   Stored in directory: /root/.cache/pip/wheels/eb/f9/9d/ea128e53c92937b3f10b15f961f100068615df83d0b7c3affc
# Successfully built sorting
# ...

# %%
import sorting
import numpy as np

vehiculos = ['avión','bicicleta','coche','motocicleta','tractor','barco','transatlántico','camión']
lista = np.random.randint(1, 10, size=(20), dtype=int)
print(lista)

sorting.bubble(lista)
print(lista)

del lista
# Out:
# [5 9 9 3 5 4 2 5 5 8 5 5 9 4 2 3 7 8 5 8]
# [2 2 3 3 4 4 5 5 5 5 5 5 5 7 8 8 8 9 9 9]

# %%
#Find common elements
A = [1,2,6,7,12,20,13,15]
B = [20,2,3,4,7,13]

for i in range(0, len(A)):
  for j in range(0, len(B)):
    if A[i] == B[j]:
      print(A[i])
# Out:
# 2
# 7
# 20
# 13
